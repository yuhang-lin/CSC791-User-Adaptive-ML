# %%
import pandas as pd
from exportCSV import exportCSV

# %%
parent = [] # initial policy 
NUM_ITERATION = 10 # repeat for given number of times
# grow a set of 10 children
# calculate the fitness (ECR or IS value of every children)
# select the best child and compare it with the parent

# %%
df = pd.read_csv("binned_data.csv")

# %%
df
# Out:
#            student  currProb              course  session priorTutorAction  \
# 0         0006-F14   1.0.1.0  226-001-BARNES-F14        1               PS
# 1         0006-F14   1.0.2.0  226-001-BARNES-F14        1               WE
# 2         0006-F14   1.0.3.0  226-001-BARNES-F14        1               WE
# 3         0006-F14   1.0.4.0  226-001-BARNES-F14        1               PS
# 4         0006-F14   2.1.1.0  226-001-BARNES-F14        1               PS
# ...            ...       ...                 ...      ...              ...
# 7163  kaprice4-S15  6.-1.3.0  226-001-BAHLER-S15        4               WE
# 7164  kaprice4-S15  6.-1.4.0  226-001-BAHLER-S15        4               PS
# 7165  kaprice4-S15  6.-1.4.1  226-001-BAHLER-S15        4               PS
# 7166  kaprice4-S15  6.-1.4.1  226-001-BAHLER-S15        4               PS
# 7167  kaprice4-S15  6.-1.4.0  226-001-BAHLER-S15        4               PS
#
#          reward  symbolicRepresentationCount  probDiff  \
# ...

# %%
df.columns
# Out:
# Index(['student', 'currProb', 'course', 'session', 'priorTutorAction',
#        'reward', 'symbolicRepresentationCount', 'probDiff',
#        'difficultProblemCountSolved', 'difficultProblemCountWE',
#        ...
#        'cumul_NextStepClickCountWE', 'cumul_PreviousStepClickCountWE',
#        'cumul_deletedApp', 'CurrPro_NumProbRule', 'CurrPro_avgProbTime',
#        'CurrPro_avgProbTimePS', 'CurrPro_avgProbTimeDeviationPS',
#        'CurrPro_avgProbTimeWE', 'CurrPro_avgProbTimeDeviationWE',
#        'CurrPro_medianProbTime'],
#       dtype='object', length=130)

# %%
df_org = pd.read_csv("MDP_Original_data.csv")

# %%
df_org.columns
# Out:
# Index(['student', 'currProb', 'course', 'session', 'priorTutorAction',
#        'reward', 'Interaction', 'hintCount', 'TotalTime', 'TotalPSTime',
#        ...
#        'cumul_NextStepClickCountWE', 'cumul_PreviousStepClickCountWE',
#        'cumul_deletedApp', 'CurrPro_NumProbRule', 'CurrPro_avgProbTime',
#        'CurrPro_avgProbTimePS', 'CurrPro_avgProbTimeDeviationPS',
#        'CurrPro_avgProbTimeWE', 'CurrPro_avgProbTimeDeviationWE',
#        'CurrPro_medianProbTime'],
#       dtype='object', length=130)

# %%
df2 = df[df_org.columns]

# %%
df2
# Out:
#            student  currProb              course  session priorTutorAction  \
# 0         0006-F14   1.0.1.0  226-001-BARNES-F14        1               PS
# 1         0006-F14   1.0.2.0  226-001-BARNES-F14        1               WE
# 2         0006-F14   1.0.3.0  226-001-BARNES-F14        1               WE
# 3         0006-F14   1.0.4.0  226-001-BARNES-F14        1               PS
# 4         0006-F14   2.1.1.0  226-001-BARNES-F14        1               PS
# ...            ...       ...                 ...      ...              ...
# 7163  kaprice4-S15  6.-1.3.0  226-001-BAHLER-S15        4               WE
# 7164  kaprice4-S15  6.-1.4.0  226-001-BAHLER-S15        4               PS
# 7165  kaprice4-S15  6.-1.4.1  226-001-BAHLER-S15        4               PS
# 7166  kaprice4-S15  6.-1.4.1  226-001-BAHLER-S15        4               PS
# 7167  kaprice4-S15  6.-1.4.0  226-001-BAHLER-S15        4               PS
#
# ...

# %%
df2.to_csv("binned_org_order.csv", index=False)
